# %%
import pandas as pd
df=pd.read_csv(r'E:\\Data_science\used_cars.csv') # r bhaneko relative path ho yesma
df.head()
# Out:
#       brand                            model  model_year      milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51,000 mi.
# 1   Hyundai                     Palisade SEL        2021  34,742 mi.
# 2     Lexus                    RX 350 RX 350        2022  22,372 mi.
# 3  INFINITI                 Q50 Hybrid Sport        2015  88,900 mi.
# 4      Audi        Q3 45 S line Premium Plus        2021   9,835 mi.
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
df['model_year'].dtypes
# Out:
# dtype('int64')

# %%
df['model'].dtypes
# Out:
# dtype('O')

# %%
df['milage'].dtypes
# Out:
# dtype('O')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   object
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 376.0+ KB

# %%
df['milage']=df['milage'].str.replace('mi.','').str.replace(',','').astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4009 entries, 0 to 4008
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   brand         4009 non-null   object
#  1   model         4009 non-null   object
#  2   model_year    4009 non-null   int64
#  3   milage        4009 non-null   float64
#  4   fuel_type     3839 non-null   object
#  5   engine        4009 non-null   object
#  6   transmission  4009 non-null   object
#  7   ext_col       4009 non-null   object
#  8   int_col       4009 non-null   object
#  9   accident      3896 non-null   object
#  10  clean_title   3413 non-null   object
#  11  price         4009 non-null   object
# dtypes: float64(1), int64(1), object(10)
# memory usage: 376.0+ KB

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
df['price']=df['price'].str.replace('$','').str.replace(',','').astype('float')

# %%
df.head(20)
# Out:
#             brand                                         model  model_year  \
# 0            Ford               Utility Police Interceptor Base        2013
# 1         Hyundai                                  Palisade SEL        2021
# 2           Lexus                                 RX 350 RX 350        2022
# 3        INFINITI                              Q50 Hybrid Sport        2015
# 4            Audi                     Q3 45 S line Premium Plus        2021
# 5           Acura                                      ILX 2.4L        2016
# 6            Audi                          S3 2.0T Premium Plus        2017
# 7             BMW                                        740 iL        2001
# 8           Lexus                                RC 350 F Sport        2021
# 9           Tesla                       Model X Long Range Plus        2020
# 10           Land  Rover Range Rover Sport 3.0 Supercharged HST        2021
# ...

# %%
df.to_csv('used_cars.csv', index=False) #original csv file lai

# %%
import re
df['engine_capacity']=df['engine'].str.extract(r'(\d+\.\d+L|\d+L|\d+\.\d Liter|\d+Liter)')

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
import re
df['engine_power']=df['engine'].str.extract(r'(\d+\.\d+HP)')

# %%
df.head(30)
# Out:
#             brand                                         model  model_year  \
# 0            Ford               Utility Police Interceptor Base        2013
# 1         Hyundai                                  Palisade SEL        2021
# 2           Lexus                                 RX 350 RX 350        2022
# 3        INFINITI                              Q50 Hybrid Sport        2015
# 4            Audi                     Q3 45 S line Premium Plus        2021
# 5           Acura                                      ILX 2.4L        2016
# 6            Audi                          S3 2.0T Premium Plus        2017
# 7             BMW                                        740 iL        2001
# 8           Lexus                                RC 350 F Sport        2021
# 9           Tesla                       Model X Long Range Plus        2020
# 10           Land  Rover Range Rover Sport 3.0 Supercharged HST        2021
# ...

# %%
df['engine_capacity']=df['engine_capacity'].str.replace('L','').str.replace('Liter','').str.replace('iter','')

# %%
df.head(20)
# Out:
#             brand                                         model  model_year  \
# 0            Ford               Utility Police Interceptor Base        2013
# 1         Hyundai                                  Palisade SEL        2021
# 2           Lexus                                 RX 350 RX 350        2022
# 3        INFINITI                              Q50 Hybrid Sport        2015
# 4            Audi                     Q3 45 S line Premium Plus        2021
# 5           Acura                                      ILX 2.4L        2016
# 6            Audi                          S3 2.0T Premium Plus        2017
# 7             BMW                                        740 iL        2001
# 8           Lexus                                RC 350 F Sport        2021
# 9           Tesla                       Model X Long Range Plus        2020
# 10           Land  Rover Range Rover Sport 3.0 Supercharged HST        2021
# ...

# %%
df['engine_power']=df['engine_power'].str.replace('HP','')

# %%
df.head(124)
# Out:
#              brand                                          model  model_year  \
# 0             Ford                Utility Police Interceptor Base        2013
# 1          Hyundai                                   Palisade SEL        2021
# 2            Lexus                                  RX 350 RX 350        2022
# 3         INFINITI                               Q50 Hybrid Sport        2015
# 4             Audi                      Q3 45 S line Premium Plus        2021
# ..             ...                                            ...         ...
# 119         Nissan                                   GT-R Premium        2010
# 120           Land  Rover Range Rover Sport 3.0L Supercharged HSE        2018
# 121         Toyota                                     Corolla LE        2010
# 122         Rivian                          R1S Adventure Package        2023
# 123  Mercedes-Benz                            C-Class C300 4MATIC        2022
#
#        milage      fuel_type  \
# ...

# %%
df['accidentOccured'] = df['accident'].apply(
    lambda x: 'Yes' if x == 'At least 1 accident or damage reported' else 'No'
)

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
df.head()
# Out:
#       brand                            model  model_year   milage  \
# 0      Ford  Utility Police Interceptor Base        2013  51000.0
# 1   Hyundai                     Palisade SEL        2021  34742.0
# 2     Lexus                    RX 350 RX 350        2022  22372.0
# 3  INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4      Audi        Q3 45 S line Premium Plus        2021   9835.0
#
#        fuel_type                                             engine  \
# 0  E85 Flex Fuel  300.0HP 3.7L V6 Cylinder Engine Flex Fuel Capa...
# 1       Gasoline                               3.8L V6 24V GDI DOHC
# 2       Gasoline                                     3.5 Liter DOHC
# 3         Hybrid  354.0HP 3.5L V6 Cylinder Engine Gas/Electric H...
# 4       Gasoline                         2.0L I4 16V GDI DOHC Turbo
#
#         transmission                 ext_col int_col  \
# 0        6-Speed A/T                   Black   Black
# ...

# %%
max(df['price'])
# Out:
# 2954083.0

# %%
df['carAge']=2025-df['model_year']

# %%
df.describe()
# Out:
#         model_year         milage         price       carAge
# count  4009.000000    4009.000000  4.009000e+03  4009.000000
# mean   2015.515590   64717.551010  4.455319e+04     9.484410
# std       6.104816   52296.599459  7.871064e+04     6.104816
# min    1974.000000     100.000000  2.000000e+03     1.000000
# 25%    2012.000000   23044.000000  1.720000e+04     5.000000
# 50%    2017.000000   52775.000000  3.100000e+04     8.000000
# 75%    2020.000000   94100.000000  4.999000e+04    13.000000
# max    2024.000000  405000.000000  2.954083e+06    51.000000

# %%
def get_car_range(price):
    if price < 100000:
        return 'low-end'
    elif price < 1000000:
        return 'mid-range'
    else:
        return 'high-end'

df['carRange'] = df['price'].apply(get_car_range)

# %%
df
# Out:
#          brand                            model  model_year   milage  \
# 0         Ford  Utility Police Interceptor Base        2013  51000.0
# 1      Hyundai                     Palisade SEL        2021  34742.0
# 2        Lexus                    RX 350 RX 350        2022  22372.0
# 3     INFINITI                 Q50 Hybrid Sport        2015  88900.0
# 4         Audi        Q3 45 S line Premium Plus        2021   9835.0
# ...        ...                              ...         ...      ...
# 4004   Bentley             Continental GT Speed        2023    714.0
# 4005      Audi             S4 3.0T Premium Plus        2022  10900.0
# 4006   Porsche                           Taycan        2022   2116.0
# 4007      Ford                     F-150 Raptor        2020  33000.0
# 4008       BMW                     X3 xDrive30i        2020  43000.0
#
#           fuel_type                                             engine  \
# ...

# %%
max(df['carRange'])
# Out:
# 'mid-range'

# %%
df[df['carRange'] == 'high-end']
# Out:
#          brand                    model  model_year   milage fuel_type  \
# 229    Bugatti  Veyron 16.4 Grand Sport        2011   6330.0  Gasoline
# 693   Maserati        Quattroporte Base        2005  32000.0  Gasoline
# 3046   Porsche          Carrera GT Base        2005   4400.0  Gasoline
#
#                                              engine  \
# 229                8.0L W16 64V GDI DOHC Twin Turbo
# 693    394.0HP 4.2L 8 Cylinder Engine Gasoline Fuel
# 3046  605.0HP 5.7L 10 Cylinder Engine Gasoline Fuel
#
#                            transmission ext_col int_col  \
# 229   7-Speed Automatic with Auto-Shift   White   White
# 693      Transmission w/Dual Shift Mode     Red   Beige
# 3046                        6-Speed M/T    Gray   Black
#
#                                     accident clean_title      price  \
# 229                            None reported         Yes  1950995.0
# 693   At least 1 accident or damage reported         Yes  2954083.0
# ...

# %%
# !git init
# Out:
# Reinitialized existing Git repository in E:/Data_science/.git/

# %%
# !cd Pandas

# %%
# !git init
# Out:
# Reinitialized existing Git repository in E:/Data_science/.git/

# %%
# !git remote add origin "https://github.com/ANOT-coder/learningPandas.git"
# Out:
# error: remote origin already exists.
